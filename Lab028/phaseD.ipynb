# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
DF = pd.read_table("Boiling_point.txt",skiprows=[0,1],names=["Pressure","Temp","Error"])
DF
# Out:
#     Pressure    Temp  Error
# 0         90  163.01   0.31
# 1        100  164.82   0.31
# 2        110  166.50   0.31
# 3        120  168.06   0.31
# 4        130  169.52   0.30
# ..       ...     ...    ...
# 87       960  217.35   0.52
# 88       970  217.67   0.52
# 89       980  217.98   0.52
# 90       990  218.30   0.52
# 91      1000  218.61   0.52
#
# [92 rows x 3 columns]

# %%
fig = plt.figure()

ax = fig.add_subplot(111)


ax.errorbar(x=DF["Temp"],xerr=DF["Error"],y=DF["Pressure"]*0.145038,label="Boiling")

ax.grid(True)
ax.set_ylabel("Pressure(psia)")
ax.set_xlabel("Temp(K)")


ax.set_yscale("log")

# %%
DFg = pd.read_table("Density_Data-01.txt",skiprows=[0,1],names=["Temperature","Pressure","Density","Uncertainty"])
DFg["Phase"] = 5

DFl = pd.read_table("Density_Data-liquid.txt",skiprows=[0,1],names=["Temperature","Pressure","Density","Uncertainty"])
DFl["Phase"] = 1

# %%
fig = plt.figure()

ax = fig.add_subplot(111)
plt.scatter(x=DFg["Temperature"],y=DFg["Pressure"]*0.00986923,c="green")
plt.scatter(x=DFl["Temperature"],y=DFl["Pressure"]*0.00986923,c="blue",marker="x")

ax.set_ylabel("Pressure(ATM)")
# Out:
# Text(0, 0.5, 'Pressure(ATM)')

# %%
fig = plt.figure()

ax = fig.add_subplot(111)
plt.scatter(x=DF["Temperature"],y=DF["Pressure"]*0.00986923,c=DF["Phase"])

#ax.set_ylabel("Pressure(ATM)")
